# %% [markdown]
# # [Título del notebook de ejercicio]
#
# Descripción del tema que se practica y cómo se relaciona con el artículo.
#
# **Artículo relacionado:** `[módulo]/[número]-[nombre].md`

# %%
import math
import random

# %% [markdown]
# ## 1. [Primera sección: implementación base]

# %%
def funcion_base(parametro):
    """Implementación dada al alumno como punto de partida."""
    pass


# Ejemplo de uso
resultado = funcion_base(ejemplo)
print(f"Resultado: {resultado}")

# %% [markdown]
# ### Ejercicio 1.1: [Nombre del ejercicio]
# Descripción del ejercicio. ¿Qué debe implementar el alumno?

# %%
# Tu solución aquí:
# ...

print("TODO: implementa [descripción]")

# Solución de referencia (comentada):
# resultado_esperado = valor
# assert tu_resultado == resultado_esperado

# %% [markdown]
# ## 2. [Segunda sección]

# %%
# Implementación de la sección 2
pass

# %% [markdown]
# ### Ejercicio 2.1: [Nombre del ejercicio]

# %%
# Tu solución:
print("TODO: [descripción del ejercicio]")

# %% [markdown]
# ## Autoevaluación
# Ejecuta esta celda para verificar tus respuestas.

# %%
# Tests de autoevaluación
# Descomenta y rellena con tus variables:

# assert tu_resultado_1 == valor_esperado_1, "Ejercicio 1.1: revisa [pista]"
# assert tu_resultado_2 == valor_esperado_2, "Ejercicio 2.1: revisa [pista]"

print("Todos los tests pasados ✅")
