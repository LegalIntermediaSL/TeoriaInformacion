# %% [markdown]
# # [Título del notebook de ejemplo]
#
# Descripción breve de qué ilustra este notebook y cómo se conecta con la teoría.
#
# **Artículo relacionado:** `[módulo]/[número]-[nombre].md`

# %%
# Imports necesarios
import math
import random
import numpy as np

# %% [markdown]
# ## 1. [Primera sección: concepto fundamental]

# %%
def funcion_principal(parametro):
    """Documentación breve."""
    pass


# Demostración
resultado = funcion_principal(valor_ejemplo)
print(f"Resultado: {resultado}")

# %% [markdown]
# ## 2. [Segunda sección: extensión o aplicación]

# %%
# Implementación de la segunda parte
pass

# %% [markdown]
# ## 3. [Verificación / comparación / visualización]

# %%
# Verificar propiedades teóricas
assert condicion_teorica, "Descripción del invariante"
